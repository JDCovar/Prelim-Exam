# %%
class me:
  my_string = 'John Marius Lawrence D. Covar'
  print(my_string)
  my_string = '202113751'
  print(my_string)
  my_string = '20'
  print(my_string)
  my_string = 'B.S. CPE'
  print(my_string)
# Out:
# John Marius Lawrence D. Covar
# 202113751
# 20
# B.S. CPE

# %%
class Student:
  def __init__(self, Name, Student_No, Age, School, Course):
    self.Name = JohnMariusLawrenceCovar
    self.Student_No = 202113751
    self.Age = 20 
    self.School = AdamsonUniversity
    self.Course = B.S.CPE

    def Display(self):
      print("School: ", self.Name())
      print("Student Number: ", self.StudentNo())
      print("Age: ", self.Age())
      print("School: ", self.School())
      print("Course: ", self.Course())
